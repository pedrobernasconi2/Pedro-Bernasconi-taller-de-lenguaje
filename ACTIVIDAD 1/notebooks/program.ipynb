# %%
import sys
import os
import pprint

from src.evaluacion import mejor_equipo_ronda
from src.acumulados import inicializar_acumulados, actualizar_acumulados
from src.resultados import mostrar_tabla
from src.ejerciciosextra import equipo_mas_constante, promedios_innovacion_presentacion

# %%
evaluaciones = [
 # Ronda 1
 {
 'EquipoA': {'innovacion': 2, 'presentacion': 1, 'errores': True},
 'EquipoB': {'innovacion': 1, 'presentacion': 0, 'errores': False},
 'EquipoC': {'innovacion': 1, 'presentacion': 2, 'errores': True},
 'EquipoD': {'innovacion': 0, 'presentacion': 1, 'errores': False},
 'EquipoE': {'innovacion': 1, 'presentacion': 1, 'errores': False}
 },
 # Ronda 2
 {
 'EquipoA': {'innovacion': 0, 'presentacion': 2, 'errores': False},
 'EquipoB': {'innovacion': 2, 'presentacion': 0, 'errores': True},
 'EquipoC': {'innovacion': 1, 'presentacion': 1, 'errores': False},
 'EquipoD': {'innovacion': 2, 'presentacion': 1, 'errores': True},
 'EquipoE': {'innovacion': 0, 'presentacion': 1, 'errores': False}
 },
 # Ronda 3
 {
 'EquipoA': {'innovacion': 3, 'presentacion': 2, 'errores': False},
 'EquipoB': {'innovacion': 1, 'presentacion': 1, 'errores': True},
 'EquipoC': {'innovacion': 2, 'presentacion': 0, 'errores': False},
 'EquipoD': {'innovacion': 1, 'presentacion': 3, 'errores': True},
 'EquipoE': {'innovacion': 2, 'presentacion': 2, 'errores': False}
 },
 # Ronda 4
 {
 'EquipoA': {'innovacion': 1, 'presentacion': 3, 'errores': True},
 'EquipoB': {'innovacion': 2, 'presentacion': 2, 'errores': False},
 'EquipoC': {'innovacion': 3, 'presentacion': 1, 'errores': False},
 'EquipoD': {'innovacion': 0, 'presentacion': 2, 'errores': True},
 'EquipoE': {'innovacion': 2, 'presentacion': 0, 'errores': False}
 },
 # Ronda 5
 {
 'EquipoA': {'innovacion': 2, 'presentacion': 2, 'errores': False},
 'EquipoB': {'innovacion': 1, 'presentacion': 3, 'errores': True},
 'EquipoC': {'innovacion': 0, 'presentacion': 2, 'errores': False},
 'EquipoD': {'innovacion': 3, 'presentacion': 1, 'errores': False},
 'EquipoE': {'innovacion': 2, 'presentacion': 3, 'errores': True}
 }
]

# %% [markdown]
# primero inicializo los acumulados con los equipos de la primera ronda

# %%
acumulados = inicializar_acumulados(evaluaciones)

# %% [markdown]
# ahora proceso cada ronda y aplico las funciones creadas para cada ronda

# %%
nro_Ronda=1 
for ronda in evaluaciones:
    mejor = mejor_equipo_ronda(ronda)
    actualizar_acumulados(acumulados, ronda, mejor[0])
    mostrar_tabla(acumulados, nro_Ronda, mejor)
    nro_Ronda= nro_Ronda + 1
# Out:
# --- Ronda 1 ---
# *EQUIPOA* (Mejor equipo)
#   Innovación: 2
#   Presentación: 1
#   Errores: 1
#   Mejores: 1
#   Total: 6
#
# EquipoC
#   Innovación: 1
#   Presentación: 2
#   Errores: 1
#   Mejores: 0
#   Total: 4
#
# EquipoE
#   Innovación: 1
#   Presentación: 1
#   Errores: 0
#   Mejores: 0
#   Total: 4
#
# EquipoB
#   Innovación: 1
#   Presentación: 0
#   Errores: 0
#   Mejores: 0
#   Total: 3
#
# EquipoD
#   Innovación: 0
#   Presentación: 1
#   Errores: 0
#   Mejores: 0
#   Total: 1
#
#
# --- Ronda 2 ---
# EquipoA
#   Innovación: 2
#   Presentación: 3
#   Errores: 1
#   Mejores: 1
#   Total: 8
#
# EquipoB
#   Innovación: 3
#   Presentación: 0
#   Errores: 1
#   Mejores: 0
#   Total: 8
#
# EquipoC
#   Innovación: 2
#   Presentación: 3
#   Errores: 1
#   Mejores: 0
#   Total: 8
#
# *EQUIPOD* (Mejor equipo)
#   Innovación: 2
#   Presentación: 2
#   Errores: 1
#   Mejores: 1
#   Total: 7
#
# EquipoE
#   Innovación: 1
#   Presentación: 2
#   Errores: 0
#   Mejores: 0
#   Total: 5
#
#
# --- Ronda 3 ---
# *EQUIPOA* (Mejor equipo)
#   Innovación: 5
#   Presentación: 5
#   Errores: 1
#   Mejores: 2
#   Total: 19
#
# EquipoC
#   Innovación: 4
#   Presentación: 3
#   Errores: 1
#   Mejores: 0
#   Total: 14
#
# EquipoE
#   Innovación: 3
#   Presentación: 4
#   Errores: 0
#   Mejores: 0
#   Total: 13
#
# EquipoD
#   Innovación: 3
#   Presentación: 5
#   Errores: 2
#   Mejores: 1
#   Total: 12
#
# EquipoB
#   Innovación: 4
#   Presentación: 1
#   Errores: 2
#   Mejores: 0
#   Total: 11
#
#
# --- Ronda 4 ---
# EquipoA
#   Innovación: 6
#   Presentación: 8
#   Errores: 2
#   Mejores: 2
#   Total: 24
#
# *EQUIPOC* (Mejor equipo)
#   Innovación: 7
#   Presentación: 4
#   Errores: 1
#   Mejores: 1
#   Total: 24
#
# EquipoB
#   Innovación: 6
#   Presentación: 3
#   Errores: 2
#   Mejores: 0
#   Total: 19
#
# EquipoE
#   Innovación: 5
#   Presentación: 4
#   Errores: 0
#   Mejores: 0
#   Total: 19
#
# EquipoD
#   Innovación: 3
#   Presentación: 7
#   Errores: 3
#   Mejores: 1
#   Total: 13
#
#
# --- Ronda 5 ---
# EquipoA
#   Innovación: 8
#   Presentación: 10
#   Errores: 2
#   Mejores: 2
#   Total: 32
#
# EquipoE
#   Innovación: 7
#   Presentación: 7
#   Errores: 1
#   Mejores: 0
#   Total: 27
#
# EquipoC
#   Innovación: 7
#   Presentación: 6
#   Errores: 1
#   Mejores: 1
#   Total: 26
#
# EquipoB
#   Innovación: 7
#   Presentación: 6
#   Errores: 3
#   Mejores: 0
#   Total: 24
#
# *EQUIPOD* (Mejor equipo)
#   Innovación: 6
#   Presentación: 8
#   Errores: 3
#   Mejores: 2
#   Total: 23

# %% [markdown]
# ahora proceso los ejercicios extra (hay que recorrer evaluaciones nuevamente ya que antes dividiamos por ronda)

# %%
equipo_constante, diferencia = equipo_mas_constante(evaluaciones)
print(f"Equipo más constante: {equipo_constante} (Diferencia: {diferencia})")

promedio_innovacion, promedio_presentacion = promedios_innovacion_presentacion(evaluaciones)
print(f"Promedio Innovación: {promedio_innovacion}")
print(f"Promedio Presentación: {promedio_presentacion}")
# Out:
# Equipo más constante: EquipoB (Diferencia: 5)
# Promedio Innovación: 1.4
# Promedio Presentación: 1.48
